# %% [markdown]
# **Module0**
# Google Colab in Python
# Data Science Fundamentals
# CRISP -DM model

# %% [markdown]
# look at the analytics maturity model and try to undestand the what and why
# the impliment a mc modeland find out what next
# find out a a prescreptive analytics model

# %% [markdown]
# apartment list in craiglist
# pandas: for dataframe (data structure that we get from pandas  is like a table, have several different columns so different datatypes can be stored),
# numpy: arrays (way to store ta, need to be of the same datatype)and matrices,
# matplotlib : plotting (if we want to create a basic chart or visiualization) seabron(easier version of matplotlib) need to be imported

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.dogplot()

# %% [markdown]
# functions, methods and classes , use paranthesis

# %%
url1="https://github.com/edavgaun/RCEL_506/raw/main/Module%203/Housing%20states/housing_tx_1.csv"
url2="https://raw.githubusercontent.com/edavgaun/RCEL_506/main/Module%203/Housing%20states/housing_tx_2.csv"

# %%
# how to use a pd library/methods are actions(verb) inside of brakets we need t provide the info
pd.read_csv(url1)
# Out:
#        Unnamed: 0                                                url  \
# 0          299768  https://houston.craigslist.org/apa/d/houston-n...
# 1          299769  https://houston.craigslist.org/apa/d/houston-f...
# 2          299770  https://houston.craigslist.org/apa/d/houston-3...
# 3          299771  https://houston.craigslist.org/apa/d/cypress-o...
# 4          299772  https://houston.craigslist.org/apa/d/houston-s...
# ...           ...                                                ...
# 15564      315518  https://wichitafalls.craigslist.org/apa/d/wich...
# 15565      315519  https://wichitafalls.craigslist.org/apa/d/wich...
# 15566      315520  https://wichitafalls.craigslist.org/apa/d/wich...
# 15567      315521  https://wichitafalls.craigslist.org/apa/d/wich...
# 15568      315522  https://wichitafalls.craigslist.org/apa/d/wich...
#
#               region  price       type  sqfeet  beds  baths  cats_allowed  \
# ...

# %%
#len will tell us the length
df=pd.concat([pd.read_csv(url1),pd.read_csv(url2)])
df.idex=range(len(df))
# Out:
# <ipython-input-8-a9b43d6a4503>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.idex=range(len(df))

# %%
#metadata to tell us details, shape is an attribute, which will describe the dataframe
df.shape
# Out:
# (31137, 21)

# %%
#metadata, we need to know the key column names that we wil use in our columns
df.columns
# Out:
# Index(['Unnamed: 0', 'url', 'region', 'price', 'type', 'sqfeet', 'beds',
#        'baths', 'cats_allowed', 'dogs_allowed', 'smoking_allowed',
#        'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished',
#        'laundry_options', 'parking_options', 'image_url', 'description', 'lat',
#        'long', 'state'],
#       dtype='object')

# %%
#use some of the data from the above  data
df=df[['region','price','type','sqfeet','beds','baths','cats_allowed','dogs_allowed']]

# %%
#the first 3 rows are displayed, hence the number 3
df.head(3)
# Out:
#      region  price       type  sqfeet  beds  baths  cats_allowed  dogs_allowed
# 0  amarillo   1125      house    1550     4    1.5             1             1
# 1    austin    999  apartment     700     1    1.0             1             1
# 2    austin    899  apartment     504     1    1.0             1             1

# %%
#to find out the last 3
df.tail(3)
# Out:
#               region  price       type  sqfeet  beds  baths  cats_allowed  \
# 15566  wichita falls    700  apartment     675     1    1.0             1
# 15567  wichita falls    675  apartment     650     1    1.0             1
# 15568  wichita falls    625  apartment     650     1    1.0             1
#
#        dogs_allowed
# 15566             1
# 15567             1
# 15568             1

# %%
#isna wll tell with true or false if data s missing(true is boolean value 0/1), we need to drop the missing data columns
df.isna().sum()
# Out:
# region          0
# price           0
# type            0
# sqfeet          0
# beds            0
# baths           0
# cats_allowed    0
# dogs_allowed    0
# dtype: int64

# %%
df.tail(3)
# Out:
#               region  price       type  sqfeet  beds  baths  cats_allowed  \
# 15566  wichita falls    700  apartment     675     1    1.0             1
# 15567  wichita falls    675  apartment     650     1    1.0             1
# 15568  wichita falls    625  apartment     650     1    1.0             1
#
#        dogs_allowed
# 15566             1
# 15567             1
# 15568             1

# %%
#automaricallly calculate the mean / avg
df.describe()
# Out:
#                price         sqfeet          beds         baths  cats_allowed  \
# count   31137.000000   31137.000000  31137.000000  31137.000000  31137.000000
# mean     1059.767929     909.325336      1.718855      1.451296      0.778045
# std      4842.566340    1153.285513      0.857806      0.594365      0.415567
# min         0.000000       1.000000      0.000000      0.000000      0.000000
# 25%       730.000000     679.000000      1.000000      1.000000      1.000000
# 50%       903.000000     840.000000      2.000000      1.000000      1.000000
# 75%      1170.000000    1048.000000      2.000000      2.000000      1.000000
# max    699799.000000  174240.000000      7.000000      5.500000      1.000000
#
#        dogs_allowed
# count  31137.000000
# mean       0.782702
# std        0.412414
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
df[df.price<3000]
# Out:
#                 region  price       type  sqfeet  beds  baths  cats_allowed  \
# 0             amarillo   1125      house    1550     4    1.5             1
# 1               austin    999  apartment     700     1    1.0             1
# 2               austin    899  apartment     504     1    1.0             1
# 3               austin   1022  apartment     581     0    1.0             1
# 4      college station   1529  apartment    1070     2    2.0             1
# ...                ...    ...        ...     ...   ...    ...           ...
# 15564    wichita falls    840  apartment     805     2    2.0             1
# 15565    wichita falls    825  apartment     805     2    2.0             1
# 15566    wichita falls    700  apartment     675     1    1.0             1
# 15567    wichita falls    675  apartment     650     1    1.0             1
# 15568    wichita falls    625  apartment     650     1    1.0             1
#
#        dogs_allowed
# 0                 1
# ...

# %%
# need to drop prices which might not be workable(here usig 4 different filters)
df=df[(df.price>1) & (df.price<3000) & (df.sqfeet>10) & (df.sqfeet<2000)]

# %%
# we need to find out the values we can find using the data provided in the columns(visiualization) like a histogram, pie chart,line plot. scatter plot,bar graph,
